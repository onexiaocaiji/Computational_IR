# %% [markdown]
# # Experimental Infrared Spectra

# %% [markdown]
# In this jupyter notebook, you can find measured infrared spectra.
#
# Please note the gas phase in some cases has been diluted with N2 to decrease interactions between the molecules under investigation.
#
# The range for both the wavenumber and the absorbance, unfortunately, is not the same for all the plots.
#
# You can also open each spectrum in a new tab for better resolution (right-click, then "Open image in a new tab").

# %% [markdown]
# ### IR spectrum 1
#
# <img src="figures/IR_spectrum1.svg" width="100%" style="float:left">

# %% [raw]
# CH3F

# %% [markdown]
# ### IR spectrum 2
#
# <img src="figures/IR_spectrum2.svg" width="100%" style="float:left">

# %% [raw]
# C6H6

# %% [markdown]
# ### IR spectrum 3
#
# <img src="figures/IR_spectrum3.svg" width="100%" style="float:left">

# %% [raw]
# CH4

# %% [markdown]
# ### IR spectrum 4
#
# <img src="figures/IR_spectrum4.svg" width="100%" style="float:left">

# %% [raw]
# CH3OH

# %% [markdown]
# ### IR spectrum 5
#
# <img src="figures/IR_spectrum5.svg" width="100%" style="float:left">

# %% [raw]
# CH2O
